# %%
import pandas as pd
import json

# Chemins des fichiers
xlsx_neg_path = r'D:\Axel\DATAS\ISTD_ALL\filtered_DB\Agromix_C18_1.5RT_Jul2023_neg_filtered.xlsx'
xlsx_pos_path = r'D:\Axel\DATAS\ISTD_ALL\filtered_DB\Agromix_C18_1.5RT_Jul2023_pos_filtered.xlsx'
json_neg_path = r'D:\Axel\DATAS\ISTD_ALL\filtered_DB\ISTD_neg_smiles_NPclass_complete.json'
json_pos_path = r'D:\Axel\DATAS\ISTD_ALL\filtered_DB\ISTD_pos_smiles_NPclass_complete.json'

# Lire les fichiers XLSX
df_neg = pd.read_excel(xlsx_neg_path)
df_pos = pd.read_excel(xlsx_pos_path)

# Lire les fichiers JSON
with open(json_neg_path, 'r') as f:
    json_neg = json.load(f)

with open(json_pos_path, 'r') as f:
    json_pos = json.load(f)

# %%
def add_np_classes(df, json_data):
    class_np_list = []
    superclass_np_list = []
    pathway_np_list = []

    for index, row in df.iterrows():
        if index < len(json_data):
            match = json_data[index]
            class_np_list.append(match.get('ClassNP', 'None'))
            superclass_np_list.append(match.get('SuperClassNP', 'None'))
            pathway_np_list.append(match.get('PathwayNP', 'None'))
        else:
            class_np_list.append('None')
            superclass_np_list.append('None')
            pathway_np_list.append('None')

    # Ajouter les nouvelles colonnes au DataFrame
    df['ClassNP'] = class_np_list
    df['SuperClassNP'] = superclass_np_list
    df['PathwayNP'] = pathway_np_list

    return df

# %%
# Appliquer la fonction aux DataFrames négatif et positif
df_neg = add_np_classes(df_neg, json_neg)
df_pos = add_np_classes(df_pos, json_pos)

# %%
df_neg.head()
# Out:
#          FILENAME PREDICTED SPECTRUMID RESOLUTION  SYNON  CHARGE  PARENTMASS  \
# 0  Cannabiflavine     false       None       None   None      -1  436.188589
# 1  Cannabiflavine     false       None       None   None      -1  436.188589
# 2  Cannabiflavine     false       None       None   None      -1  436.188589
# 3  Cannabiflavine     false       None       None   None      -1  436.188589
# 4  Cannabiflavine     false       None       None   None      -1  436.188589
#
#   IONIZATION  MSLEVEL FRAGMENTATIONMODE  ... COLLISIONENERGY    FORMULA  \
# 0     LC-ESI        2               HCD  ...              40   C26H28O6
# 1     LC-ESI        2               HCD  ...              40   C26H28O6
# 2     LC-ESI        2               HCD  ...              40   C26H28O6
# 3     LC-ESI        2               HCD  ...              40   C26H28O6
# 4     LC-ESI        2               HCD  ...              40   C26H28O6
#
#   RETENTIONTIME    IONMODE COMMENT NUM PEAKS  \
# 0     12.204346   negative    None        15
# 1     12.204346   negative    None        18
# 2     12.185153   negative    None        27
# 3     12.204346   negative    None        21
# 4     12.204346   negative    None        28
#
#                                           PEAKS_LIST   ClassNP  SuperClassNP  \
# 0  50.500053   0.11768326037248351\n64.430191   0...  Flavones    Flavonoids
# 1  50.553676   0.12054946959058127\n67.696075   0...  Flavones    Flavonoids
# 2  51.062583   0.0639230280068913\n54.760917   0....  Flavones    Flavonoids
# 3  52.670436   0.021372941820006364\n68.131675   ...  Flavones    Flavonoids
# 4  53.104686   0.07757619219921666\n56.457077   0...  Flavones    Flavonoids
#
#                          PathwayNP
# 0  Shikimates and Phenylpropanoids
# 1  Shikimates and Phenylpropanoids
# 2  Shikimates and Phenylpropanoids
# 3  Shikimates and Phenylpropanoids
# 4  Shikimates and Phenylpropanoids
#
# [5 rows x 28 columns]

# %%
df_pos.head()
# Out:
#          FILENAME PREDICTED SPECTRUMID RESOLUTION  SYNON  CHARGE  PARENTMASS  \
# 0  Cannabiflavine     false       None       None   None       1  436.188589
# 1  Cannabiflavine     false       None       None   None       1  436.188589
# 2  Cannabiflavine     false       None       None   None       1  436.188589
# 3  Cannabiflavine     false       None       None   None       1  436.188589
# 4  Cannabiflavine     false       None       None   None       1  436.188589
#
#   IONIZATION  MSLEVEL FRAGMENTATIONMODE  ... COLLISIONENERGY    FORMULA  \
# 0     LC-ESI        2               HCD  ...              40   C26H28O6
# 1     LC-ESI        2               HCD  ...              40   C26H28O6
# 2     LC-ESI        2               HCD  ...              40   C26H28O6
# 3     LC-ESI        2               HCD  ...              40   C26H28O6
# 4     LC-ESI        2               HCD  ...              40   C26H28O6
#
#   RETENTIONTIME    IONMODE COMMENT NUM PEAKS  \
# 0     12.195385   positive    None        13
# 1     12.195385   positive    None        12
# 2     12.195385   positive    None        24
# 3     12.195385   positive    None        27
# 4     12.195385   positive    None        16
#
#                                           PEAKS_LIST   ClassNP  SuperClassNP  \
# 0  123.0074    0.0128567652745558\n141.018096  0....  Flavones    Flavonoids
# 1  141.01828   0.01588808849822114\n149.059432  0...  Flavones    Flavonoids
# 2  54.302429   0.049741077709372666\n55.580223   ...  Flavones    Flavonoids
# 3  66.850311   0.019517537168994188\n67.05455    ...  Flavones    Flavonoids
# 4  67.388626   0.014056011392514728\n67.392601   ...  Flavones    Flavonoids
#
#                          PathwayNP
# 0  Shikimates and Phenylpropanoids
# 1  Shikimates and Phenylpropanoids
# 2  Shikimates and Phenylpropanoids
# 3  Shikimates and Phenylpropanoids
# 4  Shikimates and Phenylpropanoids
#
# [5 rows x 28 columns]

# %%
# Concaténer les deux DataFrames
df_combined = pd.concat([df_neg, df_pos])

# Ajouter la colonne `shortinchikey` en extrayant les 14 premiers caractères de `INCHIKEY`
df_combined['shortinchikey'] = df_combined['INCHIKEY'].str[:14]

# Colonnes à garder
cols_to_keep = [
    'FILENAME', 'PARENTMASS', 'NAME', 'PRECURSORMZ', 'PRECURSORTYPE',
    'SMILES', 'INCHI', 'INCHIKEY', 'shortinchikey', 'FORMULA', 'RETENTIONTIME', 'IONMODE',
    'ClassNP', 'SuperClassNP', 'PathwayNP'
]

# Filtrer les colonnes
df_filtered = df_combined[cols_to_keep]

# Enregistrer le résultat dans un nouveau fichier XLSX
df_filtered.to_excel(r'D:\Axel\DATAS\ISTD_ALL\filtered_DB\Agromix_C18_1.5RT_Jul2023_filtered_combined_np.xlsx',
                     index=False)
