# %%
from anytree import Node, RenderTree
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\Axel\Documents\PYTHON\MSP_V3\FragHub\datas\GRAPH_CONSTRUCT_SOLUTIONS.xlsx", sheet_name="Waters")
df = df.astype(str)
df_dict = df.to_dict(orient='records')

# %%
trees = {}

for row in df_dict:
    if row['MARQUES'] not in trees:
        trees[row['MARQUES']] = Node(row['MARQUES'])
    node = trees[row['MARQUES']]
    for col in ['MODELS', 'SPECTRUM_TYPE', 'INSTRUMENT_TYPE', 'IONISATION', 'RESOLUTION', 'SOLUTION']:
        try:
            node = [child for child in node.children if child.name == row[col]][0]
        except IndexError:
            node = Node(row[col], parent=node)

# %%
for tree in trees.values():
    for pre, fill, node in RenderTree(tree):
        print("%s%s" % (pre, node.name))
# Out:
# UNKNOWN
# ├── 2690
# │   ├── LC
# │   │   ├── QQQ
# │   │   │   ├── ESI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  2690, LC-ESI-QQQ, LOW
# │   │   │   └── UNKNOWN
# │   │   │       └── LOW
# │   │   │           └── Waters  2690, LC-UNKNOWN-QQQ, LOW
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── LOW
# │   │       │       └── Waters  2690, LC-ESI-UNKNOWN, LOW
# │   │       └── UNKNOWN
# │   │           └── LOW
# │   │               └── Waters  2690, LC-UNKNOWN-UNKNOWN, LOW
# │   └── UNKNOWN
# │       ├── QQQ
# │       │   ├── ESI
# │       │   │   └── LOW
# │       │   │       └── Waters  2690, UNKNOWN-ESI-QQQ, LOW
# │       │   └── UNKNOWN
# │       │       └── LOW
# │       │           └── Waters  2690, UNKNOWN-UNKNOWN-QQQ, LOW
# │       └── UNKNOWN
# │           └── ESI
# │               └── LOW
# │                   └── Waters  2690, UNKNOWN-ESI-UNKNOWN, LOW
# ├── Fisons VG Platform
# │   ├── LC
# │   │   ├── Q
# │   │   │   ├── ESI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  Fisons VG Platform, LC-ESI-Q, LOW
# │   │   │   └── UNKNOWN
# │   │   │       └── LOW
# │   │   │           └── Waters  Fisons VG Platform, LC-UNKNOWN-Q, LOW
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── LOW
# │   │       │       └── Waters  Fisons VG Platform, LC-ESI-UNKNOWN, LOW
# │   │       └── UNKNOWN
# │   │           └── LOW
# │   │               └── Waters  Fisons VG Platform, LC-UNKNOWN-UNKNOWN, LOW
# │   └── UNKNOWN
# │       ├── Q
# │       │   ├── ESI
# │       │   │   └── LOW
# │       │   │       └── Waters  Fisons VG Platform, UNKNOWN-ESI-Q, LOW
# │       │   └── UNKNOWN
# │       │       └── LOW
# │       │           └── Waters  Fisons VG Platform, UNKNOWN-UNKNOWN-Q, LOW
# │       └── UNKNOWN
# │           └── ESI
# │               └── LOW
# │                   └── Waters  Fisons VG Platform, UNKNOWN-ESI-UNKNOWN, LOW
# ├── LCT Micromass
# │   ├── LC
# │   │   ├── TOF
# │   │   │   ├── ESI
# │   │   │   │   └── HIGH
# │   │   │   │       └── Waters  LCT Micromass, LC-ESI-TOF, HIGH
# │   │   │   └── UNKNOWN
# │   │   │       └── HIGH
# │   │   │           └── Waters  LCT Micromass, LC-UNKNOWN-TOF, HIGH
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── HIGH
# │   │       │       └── Waters  LCT Micromass, LC-ESI-UNKNOWN, HIGH
# │   │       └── UNKNOWN
# │   │           └── HIGH
# │   │               └── Waters  LCT Micromass, LC-UNKNOWN-UNKNOWN, HIGH
# │   └── UNKNOWN
# │       ├── TOF
# │       │   ├── ESI
# │       │   │   └── HIGH
# │       │   │       └── Waters  LCT Micromass, UNKNOWN-ESI-TOF, HIGH
# │       │   └── UNKNOWN
# │       │       └── HIGH
# │       │           └── Waters  LCT Micromass, UNKNOWN-UNKNOWN-TOF, HIGH
# │       └── UNKNOWN
# │           └── ESI
# │               └── HIGH
# │                   └── Waters  LCT Micromass, UNKNOWN-ESI-UNKNOWN, HIGH
# ├── Micromass QTOF II
# │   ├── LC
# │   │   ├── QTOF
# │   │   │   ├── ESI
# │   │   │   │   └── HIGH
# │   │   │   │       └── Waters  Micromass QTOF II, LC-ESI-QTOF, HIGH
# │   │   │   └── UNKNOWN
# │   │   │       └── HIGH
# │   │   │           └── Waters  Micromass QTOF II, LC-UNKNOWN-QTOF, HIGH
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── HIGH
# │   │       │       └── Waters  Micromass QTOF II, LC-ESI-UNKNOWN, HIGH
# │   │       └── UNKNOWN
# │   │           └── HIGH
# │   │               └── Waters  Micromass QTOF II, LC-UNKNOWN-UNKNOWN, HIGH
# │   └── UNKNOWN
# │       ├── QTOF
# │       │   ├── ESI
# │       │   │   └── HIGH
# │       │   │       └── Waters  Micromass QTOF II, UNKNOWN-ESI-QTOF, HIGH
# │       │   └── UNKNOWN
# │       │       └── HIGH
# │       │           └── Waters  Micromass QTOF II, UNKNOWN-UNKNOWN-QTOF, HIGH
# │       └── UNKNOWN
# │           └── ESI
# │               └── HIGH
# │                   └── Waters  Micromass QTOF II, UNKNOWN-ESI-UNKNOWN, HIGH
# ├── Micromass Quatro Micro API
# │   ├── LC
# │   │   ├── QQ
# │   │   │   ├── ESI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  Micromass Quatro Micro API, LC-ESI-QQ, LOW
# │   │   │   └── UNKNOWN
# │   │   │       └── LOW
# │   │   │           └── Waters  Micromass Quatro Micro API, LC-UNKNOWN-QQ, LOW
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── LOW
# │   │       │       └── Waters  Micromass Quatro Micro API, LC-ESI-UNKNOWN, LOW
# │   │       └── UNKNOWN
# │   │           └── LOW
# │   │               └── Waters  Micromass Quatro Micro API, LC-UNKNOWN-UNKNOWN, LOW
# │   └── UNKNOWN
# │       ├── QQ
# │       │   ├── ESI
# │       │   │   └── LOW
# │       │   │       └── Waters  Micromass Quatro Micro API, UNKNOWN-ESI-QQ, LOW
# │       │   └── UNKNOWN
# │       │       └── LOW
# │       │           └── Waters  Micromass Quatro Micro API, UNKNOWN-UNKNOWN-QQ, LOW
# │       └── UNKNOWN
# │           └── ESI
# │               └── LOW
# │                   └── Waters  Micromass Quatro Micro API, UNKNOWN-ESI-UNKNOWN, LOW
# ├── Micromass Quattro II
# │   ├── LC
# │   │   ├── QQQ
# │   │   │   ├── ESI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  Micromass Quattro II, LC-ESI-QQQ, LOW
# │   │   │   └── UNKNOWN
# │   │   │       └── LOW
# │   │   │           └── Waters  Micromass Quattro II, LC-UNKNOWN-QQQ, LOW
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── LOW
# │   │       │       └── Waters  Micromass Quattro II, LC-ESI-UNKNOWN, LOW
# │   │       └── UNKNOWN
# │   │           └── LOW
# │   │               └── Waters  Micromass Quattro II, LC-UNKNOWN-UNKNOWN, LOW
# │   └── UNKNOWN
# │       ├── QQQ
# │       │   ├── ESI
# │       │   │   └── LOW
# │       │   │       └── Waters  Micromass Quattro II, UNKNOWN-ESI-QQQ, LOW
# │       │   └── UNKNOWN
# │       │       └── LOW
# │       │           └── Waters  Micromass Quattro II, UNKNOWN-UNKNOWN-QQQ, LOW
# │       └── UNKNOWN
# │           └── ESI
# │               └── LOW
# │                   └── Waters  Micromass Quattro II, UNKNOWN-ESI-UNKNOWN, LOW
# ├── Micromass Quattro Micro
# │   ├── LC
# │   │   ├── QQQ
# │   │   │   ├── ESI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  Micromass Quattro Micro, LC-ESI-QQQ, LOW
# │   │   │   └── UNKNOWN
# │   │   │       └── LOW
# │   │   │           └── Waters  Micromass Quattro Micro, LC-UNKNOWN-QQQ, LOW
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── LOW
# │   │       │       └── Waters  Micromass Quattro Micro, LC-ESI-UNKNOWN, LOW
# │   │       └── UNKNOWN
# │   │           └── LOW
# │   │               └── Waters  Micromass Quattro Micro, LC-UNKNOWN-UNKNOWN, LOW
# │   └── UNKNOWN
# │       ├── QQQ
# │       │   ├── ESI
# │       │   │   └── LOW
# │       │   │       └── Waters  Micromass Quattro Micro, UNKNOWN-ESI-QQQ, LOW
# │       │   └── UNKNOWN
# │       │       └── LOW
# │       │           └── Waters  Micromass Quattro Micro, UNKNOWN-UNKNOWN-QQQ, LOW
# │       └── UNKNOWN
# │           └── ESI
# │               └── LOW
# │                   └── Waters  Micromass Quattro Micro, UNKNOWN-ESI-UNKNOWN, LOW
# ├── Micromass Quattro Premier
# │   ├── LC
# │   │   ├── QQ
# │   │   │   ├── ESI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  Micromass Quattro Premier, LC-ESI-QQ, LOW
# │   │   │   └── UNKNOWN
# │   │   │       └── LOW
# │   │   │           └── Waters  Micromass Quattro Premier, LC-UNKNOWN-QQ, LOW
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── LOW
# │   │       │       └── Waters  Micromass Quattro Premier, LC-ESI-UNKNOWN, LOW
# │   │       └── UNKNOWN
# │   │           └── LOW
# │   │               └── Waters  Micromass Quattro Premier, LC-UNKNOWN-UNKNOWN, LOW
# │   └── UNKNOWN
# │       ├── QQ
# │       │   ├── ESI
# │       │   │   └── LOW
# │       │   │       └── Waters  Micromass Quattro Premier, UNKNOWN-ESI-QQ, LOW
# │       │   └── UNKNOWN
# │       │       └── LOW
# │       │           └── Waters  Micromass Quattro Premier, UNKNOWN-UNKNOWN-QQ, LOW
# │       └── UNKNOWN
# │           └── ESI
# │               └── LOW
# │                   └── Waters  Micromass Quattro Premier, UNKNOWN-ESI-UNKNOWN, LOW
# ├── Micromass Quattro Ultima
# │   ├── LC
# │   │   ├── QQ
# │   │   │   ├── ESI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  Micromass Quattro Ultima, LC-ESI-QQ, LOW
# │   │   │   └── UNKNOWN
# │   │   │       └── LOW
# │   │   │           └── Waters  Micromass Quattro Ultima, LC-UNKNOWN-QQ, LOW
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── LOW
# │   │       │       └── Waters  Micromass Quattro Ultima, LC-ESI-UNKNOWN, LOW
# │   │       └── UNKNOWN
# │   │           └── LOW
# │   │               └── Waters  Micromass Quattro Ultima, LC-UNKNOWN-UNKNOWN, LOW
# │   └── UNKNOWN
# │       ├── QQ
# │       │   ├── ESI
# │       │   │   └── LOW
# │       │   │       └── Waters  Micromass Quattro Ultima, UNKNOWN-ESI-QQ, LOW
# │       │   └── UNKNOWN
# │       │       └── LOW
# │       │           └── Waters  Micromass Quattro Ultima, UNKNOWN-UNKNOWN-QQ, LOW
# │       └── UNKNOWN
# │           └── ESI
# │               └── LOW
# │                   └── Waters  Micromass Quattro Ultima, UNKNOWN-ESI-UNKNOWN, LOW
# ├── QTOF Micro
# │   ├── LC
# │   │   ├── QTOF
# │   │   │   ├── ESI
# │   │   │   │   └── HIGH
# │   │   │   │       └── Waters  QTOF Micro, LC-ESI-QTOF, HIGH
# │   │   │   └── UNKNOWN
# │   │   │       └── HIGH
# │   │   │           └── Waters  QTOF Micro, LC-UNKNOWN-QTOF, HIGH
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── HIGH
# │   │       │       └── Waters  QTOF Micro, LC-ESI-UNKNOWN, HIGH
# │   │       └── UNKNOWN
# │   │           └── HIGH
# │   │               └── Waters  QTOF Micro, LC-UNKNOWN-UNKNOWN, HIGH
# │   └── UNKNOWN
# │       ├── QTOF
# │       │   ├── ESI
# │       │   │   └── HIGH
# │       │   │       └── Waters  QTOF Micro, UNKNOWN-ESI-QTOF, HIGH
# │       │   └── UNKNOWN
# │       │       └── HIGH
# │       │           └── Waters  QTOF Micro, UNKNOWN-UNKNOWN-QTOF, HIGH
# │       └── UNKNOWN
# │           └── ESI
# │               └── HIGH
# │                   └── Waters  QTOF Micro, UNKNOWN-ESI-UNKNOWN, HIGH
# ├── QTOF Premier
# │   ├── LC
# │   │   ├── QTOF
# │   │   │   ├── ESI
# │   │   │   │   └── HIGH
# │   │   │   │       └── Waters  QTOF Premier, LC-ESI-QTOF, HIGH
# │   │   │   └── UNKNOWN
# │   │   │       └── HIGH
# │   │   │           └── Waters  QTOF Premier, LC-UNKNOWN-QTOF, HIGH
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── HIGH
# │   │       │       └── Waters  QTOF Premier, LC-ESI-UNKNOWN, HIGH
# │   │       └── UNKNOWN
# │   │           └── HIGH
# │   │               └── Waters  QTOF Premier, LC-UNKNOWN-UNKNOWN, HIGH
# │   └── UNKNOWN
# │       ├── QTOF
# │       │   ├── ESI
# │       │   │   └── HIGH
# │       │   │       └── Waters  QTOF Premier, UNKNOWN-ESI-QTOF, HIGH
# │       │   └── UNKNOWN
# │       │       └── HIGH
# │       │           └── Waters  QTOF Premier, UNKNOWN-UNKNOWN-QTOF, HIGH
# │       └── UNKNOWN
# │           └── ESI
# │               └── HIGH
# │                   └── Waters  QTOF Premier, UNKNOWN-ESI-UNKNOWN, HIGH
# ├── Quattro
# │   ├── LC
# │   │   ├── QQQ
# │   │   │   ├── ESI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  Quattro, LC-ESI-QQQ, LOW
# │   │   │   └── UNKNOWN
# │   │   │       └── LOW
# │   │   │           └── Waters  Quattro, LC-UNKNOWN-QQQ, LOW
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── LOW
# │   │       │       └── Waters  Quattro, LC-ESI-UNKNOWN, LOW
# │   │       └── UNKNOWN
# │   │           └── LOW
# │   │               └── Waters  Quattro, LC-UNKNOWN-UNKNOWN, LOW
# │   └── UNKNOWN
# │       ├── QQQ
# │       │   ├── ESI
# │       │   │   └── LOW
# │       │   │       └── Waters  Quattro, UNKNOWN-ESI-QQQ, LOW
# │       │   └── UNKNOWN
# │       │       └── LOW
# │       │           └── Waters  Quattro, UNKNOWN-UNKNOWN-QQQ, LOW
# │       └── UNKNOWN
# │           └── ESI
# │               └── LOW
# │                   └── Waters  Quattro, UNKNOWN-ESI-UNKNOWN, LOW
# ├── Quattro II
# │   ├── LC
# │   │   ├── QQQ
# │   │   │   ├── ESI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  Quattro II, LC-ESI-QQQ, LOW
# │   │   │   └── UNKNOWN
# │   │   │       └── LOW
# │   │   │           └── Waters  Quattro II, LC-UNKNOWN-QQQ, LOW
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── LOW
# │   │       │       └── Waters  Quattro II, LC-ESI-UNKNOWN, LOW
# │   │       └── UNKNOWN
# │   │           └── LOW
# │   │               └── Waters  Quattro II, LC-UNKNOWN-UNKNOWN, LOW
# │   └── UNKNOWN
# │       ├── QQQ
# │       │   ├── ESI
# │       │   │   └── LOW
# │       │   │       └── Waters  Quattro II, UNKNOWN-ESI-QQQ, LOW
# │       │   └── UNKNOWN
# │       │       └── LOW
# │       │           └── Waters  Quattro II, UNKNOWN-UNKNOWN-QQQ, LOW
# │       └── UNKNOWN
# │           └── ESI
# │               └── LOW
# │                   └── Waters  Quattro II, UNKNOWN-ESI-UNKNOWN, LOW
# ├── Quattro micro
# │   ├── LC
# │   │   ├── QQQ
# │   │   │   ├── ESI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  Quattro micro, LC-ESI-QQQ, LOW
# │   │   │   └── UNKNOWN
# │   │   │       └── LOW
# │   │   │           └── Waters  Quattro micro, LC-UNKNOWN-QQQ, LOW
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── LOW
# │   │       │       └── Waters  Quattro micro, LC-ESI-UNKNOWN, LOW
# │   │       └── UNKNOWN
# │   │           └── LOW
# │   │               └── Waters  Quattro micro, LC-UNKNOWN-UNKNOWN, LOW
# │   └── UNKNOWN
# │       ├── QQQ
# │       │   ├── ESI
# │       │   │   └── LOW
# │       │   │       └── Waters  Quattro micro, UNKNOWN-ESI-QQQ, LOW
# │       │   └── UNKNOWN
# │       │       └── LOW
# │       │           └── Waters  Quattro micro, UNKNOWN-UNKNOWN-QQQ, LOW
# │       └── UNKNOWN
# │           └── ESI
# │               └── LOW
# │                   └── Waters  Quattro micro, UNKNOWN-ESI-UNKNOWN, LOW
# ├── Quattro Premier XE
# │   ├── LC
# │   │   ├── QIT
# │   │   │   ├── ESI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  Quattro Premier XE, LC-ESI-QIT, LOW
# │   │   │   └── UNKNOWN
# │   │   │       └── LOW
# │   │   │           └── Waters  Quattro Premier XE, LC-UNKNOWN-QIT, LOW
# │   │   ├── QQ
# │   │   │   ├── ESI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  Quattro Premier XE, LC-ESI-QQ, LOW
# │   │   │   └── UNKNOWN
# │   │   │       └── LOW
# │   │   │           └── Waters  Quattro Premier XE, LC-UNKNOWN-QQ, LOW
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── LOW
# │   │       │       └── Waters  Quattro Premier XE, LC-ESI-UNKNOWN, LOW
# │   │       └── UNKNOWN
# │   │           └── LOW
# │   │               └── Waters  Quattro Premier XE, LC-UNKNOWN-UNKNOWN, LOW
# │   └── UNKNOWN
# │       ├── QIT
# │       │   ├── ESI
# │       │   │   └── LOW
# │       │   │       └── Waters  Quattro Premier XE, UNKNOWN-ESI-QIT, LOW
# │       │   └── UNKNOWN
# │       │       └── LOW
# │       │           └── Waters  Quattro Premier XE, UNKNOWN-UNKNOWN-QIT, LOW
# │       ├── QQ
# │       │   ├── ESI
# │       │   │   └── LOW
# │       │   │       └── Waters  Quattro Premier XE, UNKNOWN-ESI-QQ, LOW
# │       │   └── UNKNOWN
# │       │       └── LOW
# │       │           └── Waters  Quattro Premier XE, UNKNOWN-UNKNOWN-QQ, LOW
# │       └── UNKNOWN
# │           └── ESI
# │               └── LOW
# │                   └── Waters  Quattro Premier XE, UNKNOWN-ESI-UNKNOWN, LOW
# ├── SYNAPT
# │   ├── LC
# │   │   ├── QTOF
# │   │   │   ├── ESI
# │   │   │   │   └── HIGH
# │   │   │   │       └── Waters  SYNAPT, LC-ESI-QTOF, HIGH
# │   │   │   └── UNKNOWN
# │   │   │       └── HIGH
# │   │   │           └── Waters  SYNAPT, LC-UNKNOWN-QTOF, HIGH
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── HIGH
# │   │       │       └── Waters  SYNAPT, LC-ESI-UNKNOWN, HIGH
# │   │       └── UNKNOWN
# │   │           └── HIGH
# │   │               └── Waters  SYNAPT, LC-UNKNOWN-UNKNOWN, HIGH
# │   └── UNKNOWN
# │       ├── QTOF
# │       │   ├── ESI
# │       │   │   └── HIGH
# │       │   │       └── Waters  SYNAPT, UNKNOWN-ESI-QTOF, HIGH
# │       │   └── UNKNOWN
# │       │       └── HIGH
# │       │           └── Waters  SYNAPT, UNKNOWN-UNKNOWN-QTOF, HIGH
# │       └── UNKNOWN
# │           └── ESI
# │               └── HIGH
# │                   └── Waters  SYNAPT, UNKNOWN-ESI-UNKNOWN, HIGH
# ├── SYNAPT-G2
# │   ├── LC
# │   │   ├── QTOF
# │   │   │   ├── ESI
# │   │   │   │   └── HIGH
# │   │   │   │       └── Waters  SYNAPT-G2, LC-ESI-QTOF, HIGH
# │   │   │   └── UNKNOWN
# │   │   │       └── HIGH
# │   │   │           └── Waters  SYNAPT-G2, LC-UNKNOWN-QTOF, HIGH
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── HIGH
# │   │       │       └── Waters  SYNAPT-G2, LC-ESI-UNKNOWN, HIGH
# │   │       └── UNKNOWN
# │   │           └── HIGH
# │   │               └── Waters  SYNAPT-G2, LC-UNKNOWN-UNKNOWN, HIGH
# │   └── UNKNOWN
# │       ├── QTOF
# │       │   ├── ESI
# │       │   │   └── HIGH
# │       │   │       └── Waters  SYNAPT-G2, UNKNOWN-ESI-QTOF, HIGH
# │       │   └── UNKNOWN
# │       │       └── HIGH
# │       │           └── Waters  SYNAPT-G2, UNKNOWN-UNKNOWN-QTOF, HIGH
# │       └── UNKNOWN
# │           └── ESI
# │               └── HIGH
# │                   └── Waters  SYNAPT-G2, UNKNOWN-ESI-UNKNOWN, HIGH
# ├── Ultima API
# │   ├── LC
# │   │   ├── QTOF
# │   │   │   ├── ESI
# │   │   │   │   └── HIGH
# │   │   │   │       └── Waters  Ultima API, LC-ESI-QTOF, HIGH
# │   │   │   └── UNKNOWN
# │   │   │       └── HIGH
# │   │   │           └── Waters  Ultima API, LC-UNKNOWN-QTOF, HIGH
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── HIGH
# │   │       │       └── Waters  Ultima API, LC-ESI-UNKNOWN, HIGH
# │   │       └── UNKNOWN
# │   │           └── HIGH
# │   │               └── Waters  Ultima API, LC-UNKNOWN-UNKNOWN, HIGH
# │   └── UNKNOWN
# │       ├── QTOF
# │       │   ├── ESI
# │       │   │   └── HIGH
# │       │   │       └── Waters  Ultima API, UNKNOWN-ESI-QTOF, HIGH
# │       │   └── UNKNOWN
# │       │       └── HIGH
# │       │           └── Waters  Ultima API, UNKNOWN-UNKNOWN-QTOF, HIGH
# │       └── UNKNOWN
# │           └── ESI
# │               └── HIGH
# │                   └── Waters  Ultima API, UNKNOWN-ESI-UNKNOWN, HIGH
# ├── VG platform
# │   ├── LC
# │   │   ├── Q
# │   │   │   ├── APCI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  VG platform, LC-APCI-Q, LOW
# │   │   │   └── UNKNOWN
# │   │   │       └── LOW
# │   │   │           └── Waters  VG platform, LC-UNKNOWN-Q, LOW
# │   │   └── UNKNOWN
# │   │       ├── APCI
# │   │       │   └── LOW
# │   │       │       └── Waters  VG platform, LC-APCI-UNKNOWN, LOW
# │   │       └── UNKNOWN
# │   │           └── LOW
# │   │               └── Waters  VG platform, LC-UNKNOWN-UNKNOWN, LOW
# │   └── UNKNOWN
# │       ├── Q
# │       │   ├── APCI
# │       │   │   └── LOW
# │       │   │       └── Waters  VG platform, UNKNOWN-APCI-Q, LOW
# │       │   └── UNKNOWN
# │       │       └── LOW
# │       │           └── Waters  VG platform, UNKNOWN-UNKNOWN-Q, LOW
# │       └── UNKNOWN
# │           └── APCI
# │               └── LOW
# │                   └── Waters  VG platform, UNKNOWN-APCI-UNKNOWN, LOW
# ├── Xevo
# │   ├── LC
# │   │   ├── QTOF
# │   │   │   ├── ESI
# │   │   │   │   └── HIGH
# │   │   │   │       └── Waters  Xevo, LC-ESI-QTOF, HIGH
# │   │   │   └── UNKNOWN
# │   │   │       └── HIGH
# │   │   │           └── Waters  Xevo, LC-UNKNOWN-QTOF, HIGH
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── HIGH
# │   │       │       └── Waters  Xevo, LC-ESI-UNKNOWN, HIGH
# │   │       └── UNKNOWN
# │   │           └── HIGH
# │   │               └── Waters  Xevo, LC-UNKNOWN-UNKNOWN, HIGH
# │   └── UNKNOWN
# │       ├── QTOF
# │       │   ├── ESI
# │       │   │   └── HIGH
# │       │   │       └── Waters  Xevo, UNKNOWN-ESI-QTOF, HIGH
# │       │   └── UNKNOWN
# │       │       └── HIGH
# │       │           └── Waters  Xevo, UNKNOWN-UNKNOWN-QTOF, HIGH
# │       └── UNKNOWN
# │           └── ESI
# │               └── HIGH
# │                   └── Waters  Xevo, UNKNOWN-ESI-UNKNOWN, HIGH
# ├── Xevo G2
# │   ├── LC
# │   │   ├── QTOF
# │   │   │   ├── ESI
# │   │   │   │   └── HIGH
# │   │   │   │       └── Waters  Xevo G2, LC-ESI-QTOF, HIGH
# │   │   │   └── UNKNOWN
# │   │   │       └── HIGH
# │   │   │           └── Waters  Xevo G2, LC-UNKNOWN-QTOF, HIGH
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── HIGH
# │   │       │       └── Waters  Xevo G2, LC-ESI-UNKNOWN, HIGH
# │   │       └── UNKNOWN
# │   │           └── HIGH
# │   │               └── Waters  Xevo G2, LC-UNKNOWN-UNKNOWN, HIGH
# │   └── UNKNOWN
# │       ├── QTOF
# │       │   ├── ESI
# │       │   │   └── HIGH
# │       │   │       └── Waters  Xevo G2, UNKNOWN-ESI-QTOF, HIGH
# │       │   └── UNKNOWN
# │       │       └── HIGH
# │       │           └── Waters  Xevo G2, UNKNOWN-UNKNOWN-QTOF, HIGH
# │       └── UNKNOWN
# │           └── ESI
# │               └── HIGH
# │                   └── Waters  Xevo G2, UNKNOWN-ESI-UNKNOWN, HIGH
# ├── Xevo G2-S
# │   ├── LC
# │   │   ├── QTOF
# │   │   │   ├── ESI
# │   │   │   │   └── HIGH
# │   │   │   │       └── Waters  Xevo G2-S, LC-ESI-QTOF, HIGH
# │   │   │   └── UNKNOWN
# │   │   │       └── HIGH
# │   │   │           └── Waters  Xevo G2-S, LC-UNKNOWN-QTOF, HIGH
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── HIGH
# │   │       │       └── Waters  Xevo G2-S, LC-ESI-UNKNOWN, HIGH
# │   │       └── UNKNOWN
# │   │           └── HIGH
# │   │               └── Waters  Xevo G2-S, LC-UNKNOWN-UNKNOWN, HIGH
# │   └── UNKNOWN
# │       ├── QTOF
# │       │   ├── ESI
# │       │   │   └── HIGH
# │       │   │       └── Waters  Xevo G2-S, UNKNOWN-ESI-QTOF, HIGH
# │       │   └── UNKNOWN
# │       │       └── HIGH
# │       │           └── Waters  Xevo G2-S, UNKNOWN-UNKNOWN-QTOF, HIGH
# │       └── UNKNOWN
# │           └── ESI
# │               └── HIGH
# │                   └── Waters  Xevo G2-S, UNKNOWN-ESI-UNKNOWN, HIGH
# ├── Xevo G2-XS
# │   ├── LC
# │   │   ├── QTOF
# │   │   │   ├── ESI
# │   │   │   │   └── HIGH
# │   │   │   │       └── Waters  Xevo G2-XS, LC-ESI-QTOF, HIGH
# │   │   │   └── UNKNOWN
# │   │   │       └── HIGH
# │   │   │           └── Waters  Xevo G2-XS, LC-UNKNOWN-QTOF, HIGH
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── HIGH
# │   │       │       └── Waters  Xevo G2-XS, LC-ESI-UNKNOWN, HIGH
# │   │       └── UNKNOWN
# │   │           └── HIGH
# │   │               └── Waters  Xevo G2-XS, LC-UNKNOWN-UNKNOWN, HIGH
# │   └── UNKNOWN
# │       ├── QTOF
# │       │   ├── ESI
# │       │   │   └── HIGH
# │       │   │       └── Waters  Xevo G2-XS, UNKNOWN-ESI-QTOF, HIGH
# │       │   └── UNKNOWN
# │       │       └── HIGH
# │       │           └── Waters  Xevo G2-XS, UNKNOWN-UNKNOWN-QTOF, HIGH
# │       └── UNKNOWN
# │           └── ESI
# │               └── HIGH
# │                   └── Waters  Xevo G2-XS, UNKNOWN-ESI-UNKNOWN, HIGH
# ├── Xevo TQ
# │   ├── LC
# │   │   ├── QQ
# │   │   │   ├── ESI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  Xevo TQ, LC-ESI-QQ, LOW
# │   │   │   └── UNKNOWN
# │   │   │       └── LOW
# │   │   │           └── Waters  Xevo TQ, LC-UNKNOWN-QQ, LOW
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── LOW
# │   │       │       └── Waters  Xevo TQ, LC-ESI-UNKNOWN, LOW
# │   │       └── UNKNOWN
# │   │           └── LOW
# │   │               └── Waters  Xevo TQ, LC-UNKNOWN-UNKNOWN, LOW
# │   └── UNKNOWN
# │       ├── QQ
# │       │   ├── ESI
# │       │   │   └── LOW
# │       │   │       └── Waters  Xevo TQ, UNKNOWN-ESI-QQ, LOW
# │       │   └── UNKNOWN
# │       │       └── LOW
# │       │           └── Waters  Xevo TQ, UNKNOWN-UNKNOWN-QQ, LOW
# │       └── UNKNOWN
# │           └── ESI
# │               └── LOW
# │                   └── Waters  Xevo TQ, UNKNOWN-ESI-UNKNOWN, LOW
# ├── Xevo TQD
# │   ├── LC
# │   │   ├── QQQ
# │   │   │   ├── ESI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  Xevo TQD, LC-ESI-QQQ, LOW
# │   │   │   └── UNKNOWN
# │   │   │       └── LOW
# │   │   │           └── Waters  Xevo TQD, LC-UNKNOWN-QQQ, LOW
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── LOW
# │   │       │       └── Waters  Xevo TQD, LC-ESI-UNKNOWN, LOW
# │   │       └── UNKNOWN
# │   │           └── LOW
# │   │               └── Waters  Xevo TQD, LC-UNKNOWN-UNKNOWN, LOW
# │   └── UNKNOWN
# │       ├── QQQ
# │       │   ├── ESI
# │       │   │   └── LOW
# │       │   │       └── Waters  Xevo TQD, UNKNOWN-ESI-QQQ, LOW
# │       │   └── UNKNOWN
# │       │       └── LOW
# │       │           └── Waters  Xevo TQD, UNKNOWN-UNKNOWN-QQQ, LOW
# │       └── UNKNOWN
# │           └── ESI
# │               └── LOW
# │                   └── Waters  Xevo TQD, UNKNOWN-ESI-UNKNOWN, LOW
# ├── Xevo TQS Micro
# │   ├── LC
# │   │   ├── QQ
# │   │   │   ├── ESI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  Xevo TQS Micro, LC-ESI-QQ, LOW
# │   │   │   └── UNKNOWN
# │   │   │       └── LOW
# │   │   │           └── Waters  Xevo TQS Micro, LC-UNKNOWN-QQ, LOW
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── LOW
# │   │       │       └── Waters  Xevo TQS Micro, LC-ESI-UNKNOWN, LOW
# │   │       └── UNKNOWN
# │   │           └── LOW
# │   │               └── Waters  Xevo TQS Micro, LC-UNKNOWN-UNKNOWN, LOW
# │   └── UNKNOWN
# │       ├── QQ
# │       │   ├── ESI
# │       │   │   └── LOW
# │       │   │       └── Waters  Xevo TQS Micro, UNKNOWN-ESI-QQ, LOW
# │       │   └── UNKNOWN
# │       │       └── LOW
# │       │           └── Waters  Xevo TQS Micro, UNKNOWN-UNKNOWN-QQ, LOW
# │       └── UNKNOWN
# │           └── ESI
# │               └── LOW
# │                   └── Waters  Xevo TQS Micro, UNKNOWN-ESI-UNKNOWN, LOW
# ├── ZQ
# │   ├── LC
# │   │   ├── ITTOF
# │   │   │   ├── APCI
# │   │   │   │   └── HIGH
# │   │   │   │       └── Waters  ZQ, LC-APCI-ITTOF, HIGH
# │   │   │   └── UNKNOWN
# │   │   │       └── HIGH
# │   │   │           └── Waters  ZQ, LC-UNKNOWN-ITTOF, HIGH
# │   │   └── UNKNOWN
# │   │       ├── APCI
# │   │       │   └── HIGH
# │   │       │       └── Waters  ZQ, LC-APCI-UNKNOWN, HIGH
# │   │       └── UNKNOWN
# │   │           └── HIGH
# │   │               └── Waters  ZQ, LC-UNKNOWN-UNKNOWN, HIGH
# │   └── UNKNOWN
# │       ├── ITTOF
# │       │   ├── APCI
# │       │   │   └── HIGH
# │       │   │       └── Waters  ZQ, UNKNOWN-APCI-ITTOF, HIGH
# │       │   └── UNKNOWN
# │       │       └── HIGH
# │       │           └── Waters  ZQ, UNKNOWN-UNKNOWN-ITTOF, HIGH
# │       └── UNKNOWN
# │           └── APCI
# │               └── HIGH
# │                   └── Waters  ZQ, UNKNOWN-APCI-UNKNOWN, HIGH
# └── UNKNOWN
#     ├── LC
#     │   ├── QQQ
#     │   │   └── ESI
#     │   │       └── LOW
#     │   │           └── UNKNOWN UNKNOWN, LC-ESI-QQQ, LOW
#     │   ├── Q
#     │   │   ├── ESI
#     │   │   │   └── LOW
#     │   │   │       └── UNKNOWN UNKNOWN, LC-ESI-Q, LOW
#     │   │   └── APCI
#     │   │       └── LOW
#     │   │           └── UNKNOWN UNKNOWN, LC-APCI-Q, LOW
#     │   ├── TOF
#     │   │   └── ESI
#     │   │       └── HIGH
#     │   │           └── UNKNOWN UNKNOWN, LC-ESI-TOF, HIGH
#     │   ├── QTOF
#     │   │   └── ESI
#     │   │       └── HIGH
#     │   │           └── UNKNOWN UNKNOWN, LC-ESI-QTOF, HIGH
#     │   ├── QQ
#     │   │   └── ESI
#     │   │       └── LOW
#     │   │           └── UNKNOWN UNKNOWN, LC-ESI-QQ, LOW
#     │   ├── QIT
#     │   │   └── ESI
#     │   │       └── LOW
#     │   │           └── UNKNOWN UNKNOWN, LC-ESI-QIT, LOW
#     │   └── ITTOF
#     │       └── APCI
#     │           └── HIGH
#     │               └── UNKNOWN UNKNOWN, LC-APCI-ITTOF, HIGH
#     └── UNKNOWN
#         ├── QQQ
#         │   └── ESI
#         │       └── LOW
#         │           └── UNKNOWN UNKNOWN, UNKNOWN-ESI-QQQ, LOW
#         ├── Q
#         │   ├── ESI
#         │   │   └── LOW
#         │   │       └── UNKNOWN UNKNOWN, UNKNOWN-ESI-Q, LOW
#         │   └── APCI
#         │       └── LOW
#         │           └── UNKNOWN UNKNOWN, UNKNOWN-APCI-Q, LOW
#         ├── TOF
#         │   └── ESI
#         │       └── HIGH
#         │           └── UNKNOWN UNKNOWN, UNKNOWN-ESI-TOF, HIGH
#         ├── QTOF
#         │   └── ESI
#         │       └── HIGH
#         │           └── UNKNOWN UNKNOWN, UNKNOWN-ESI-QTOF, HIGH
#         ├── QQ
#         │   └── ESI
#         │       └── LOW
#         │           └── UNKNOWN UNKNOWN, UNKNOWN-ESI-QQ, LOW
#         ├── QIT
#         │   └── ESI
#         │       └── LOW
#         │           └── UNKNOWN UNKNOWN, UNKNOWN-ESI-QIT, LOW
#         └── ITTOF
#             └── APCI
#                 └── HIGH
#                     └── UNKNOWN UNKNOWN, UNKNOWN-APCI-ITTOF, HIGH
# Waters
# ├── instrument
# │   ├── LC
# │   │   ├── QQQ
# │   │   │   └── ESI
# │   │   │       └── LOW
# │   │   │           └── Waters  instrument, LC-ESI-QQQ, LOW
# │   │   ├── Q
# │   │   │   ├── ESI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  instrument, LC-ESI-Q, LOW
# │   │   │   └── APCI
# │   │   │       └── LOW
# │   │   │           └── Waters  instrument, LC-APCI-Q, LOW
# │   │   ├── TOF
# │   │   │   └── ESI
# │   │   │       └── HIGH
# │   │   │           └── Waters  instrument, LC-ESI-TOF, HIGH
# │   │   ├── QTOF
# │   │   │   └── ESI
# │   │   │       └── HIGH
# │   │   │           └── Waters  instrument, LC-ESI-QTOF, HIGH
# │   │   ├── QQ
# │   │   │   └── ESI
# │   │   │       └── LOW
# │   │   │           └── Waters  instrument, LC-ESI-QQ, LOW
# │   │   ├── QIT
# │   │   │   └── ESI
# │   │   │       └── LOW
# │   │   │           └── Waters  instrument, LC-ESI-QIT, LOW
# │   │   └── ITTOF
# │   │       └── APCI
# │   │           └── HIGH
# │   │               └── Waters  instrument, LC-APCI-ITTOF, HIGH
# │   └── UNKNOWN
# │       ├── QQQ
# │       │   └── ESI
# │       │       └── LOW
# │       │           └── Waters  instrument, UNKNOWN-ESI-QQQ, LOW
# │       ├── Q
# │       │   ├── ESI
# │       │   │   └── LOW
# │       │   │       └── Waters  instrument, UNKNOWN-ESI-Q, LOW
# │       │   └── APCI
# │       │       └── LOW
# │       │           └── Waters  instrument, UNKNOWN-APCI-Q, LOW
# │       ├── TOF
# │       │   └── ESI
# │       │       └── HIGH
# │       │           └── Waters  instrument, UNKNOWN-ESI-TOF, HIGH
# │       ├── QTOF
# │       │   └── ESI
# │       │       └── HIGH
# │       │           └── Waters  instrument, UNKNOWN-ESI-QTOF, HIGH
# │       ├── QQ
# │       │   └── ESI
# │       │       └── LOW
# │       │           └── Waters  instrument, UNKNOWN-ESI-QQ, LOW
# │       ├── QIT
# │       │   └── ESI
# │       │       └── LOW
# │       │           └── Waters  instrument, UNKNOWN-ESI-QIT, LOW
# │       └── ITTOF
# │           └── APCI
# │               └── HIGH
# │                   └── Waters  instrument, UNKNOWN-APCI-ITTOF, HIGH
# ├── 2690
# │   ├── UNKNOWN
# │   │   ├── QQQ
# │   │   │   ├── ESI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  2690, UNKNOWN-ESI-QQQ, LOW
# │   │   │   └── UNKNOWN
# │   │   │       └── LOW
# │   │   │           └── Waters  2690, UNKNOWN-UNKNOWN-QQQ, LOW
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── LOW
# │   │       │       └── Waters  2690, UNKNOWN-ESI-UNKNOWN, LOW
# │   │       └── UNKNOWN
# │   │           └── LOW
# │   │               └── Waters  2690, UNKNOWN-UNKNOWN-UNKNOWN, LOW
# │   └── LC
# │       ├── UNKNOWN
# │       │   ├── ESI
# │       │   │   └── LOW
# │       │   │       └── Waters  2690, LC-ESI-UNKNOWN, LOW
# │       │   └── UNKNOWN
# │       │       └── LOW
# │       │           └── Waters  2690, LC-UNKNOWN-UNKNOWN, LOW
# │       └── QQQ
# │           └── UNKNOWN
# │               └── LOW
# │                   └── Waters  2690, LC-UNKNOWN-QQQ, LOW
# ├── Fisons VG Platform
# │   ├── UNKNOWN
# │   │   ├── Q
# │   │   │   ├── ESI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  Fisons VG Platform, UNKNOWN-ESI-Q, LOW
# │   │   │   └── UNKNOWN
# │   │   │       └── LOW
# │   │   │           └── Waters  Fisons VG Platform, UNKNOWN-UNKNOWN-Q, LOW
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── LOW
# │   │       │       └── Waters  Fisons VG Platform, UNKNOWN-ESI-UNKNOWN, LOW
# │   │       └── UNKNOWN
# │   │           └── LOW
# │   │               └── Waters  Fisons VG Platform, UNKNOWN-UNKNOWN-UNKNOWN, LOW
# │   └── LC
# │       ├── UNKNOWN
# │       │   ├── ESI
# │       │   │   └── LOW
# │       │   │       └── Waters  Fisons VG Platform, LC-ESI-UNKNOWN, LOW
# │       │   └── UNKNOWN
# │       │       └── LOW
# │       │           └── Waters  Fisons VG Platform, LC-UNKNOWN-UNKNOWN, LOW
# │       └── Q
# │           └── UNKNOWN
# │               └── LOW
# │                   └── Waters  Fisons VG Platform, LC-UNKNOWN-Q, LOW
# ├── LCT Micromass
# │   ├── UNKNOWN
# │   │   ├── TOF
# │   │   │   ├── ESI
# │   │   │   │   └── HIGH
# │   │   │   │       └── Waters  LCT Micromass, UNKNOWN-ESI-TOF, HIGH
# │   │   │   └── UNKNOWN
# │   │   │       └── HIGH
# │   │   │           └── Waters  LCT Micromass, UNKNOWN-UNKNOWN-TOF, HIGH
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── HIGH
# │   │       │       └── Waters  LCT Micromass, UNKNOWN-ESI-UNKNOWN, HIGH
# │   │       └── UNKNOWN
# │   │           └── HIGH
# │   │               └── Waters  LCT Micromass, UNKNOWN-UNKNOWN-UNKNOWN, HIGH
# │   └── LC
# │       ├── UNKNOWN
# │       │   ├── ESI
# │       │   │   └── HIGH
# │       │   │       └── Waters  LCT Micromass, LC-ESI-UNKNOWN, HIGH
# │       │   └── UNKNOWN
# │       │       └── HIGH
# │       │           └── Waters  LCT Micromass, LC-UNKNOWN-UNKNOWN, HIGH
# │       └── TOF
# │           └── UNKNOWN
# │               └── HIGH
# │                   └── Waters  LCT Micromass, LC-UNKNOWN-TOF, HIGH
# ├── Micromass QTOF II
# │   ├── UNKNOWN
# │   │   ├── QTOF
# │   │   │   ├── ESI
# │   │   │   │   └── HIGH
# │   │   │   │       └── Waters  Micromass QTOF II, UNKNOWN-ESI-QTOF, HIGH
# │   │   │   └── UNKNOWN
# │   │   │       └── HIGH
# │   │   │           └── Waters  Micromass QTOF II, UNKNOWN-UNKNOWN-QTOF, HIGH
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── HIGH
# │   │       │       └── Waters  Micromass QTOF II, UNKNOWN-ESI-UNKNOWN, HIGH
# │   │       └── UNKNOWN
# │   │           └── HIGH
# │   │               └── Waters  Micromass QTOF II, UNKNOWN-UNKNOWN-UNKNOWN, HIGH
# │   └── LC
# │       ├── UNKNOWN
# │       │   ├── ESI
# │       │   │   └── HIGH
# │       │   │       └── Waters  Micromass QTOF II, LC-ESI-UNKNOWN, HIGH
# │       │   └── UNKNOWN
# │       │       └── HIGH
# │       │           └── Waters  Micromass QTOF II, LC-UNKNOWN-UNKNOWN, HIGH
# │       └── QTOF
# │           └── UNKNOWN
# │               └── HIGH
# │                   └── Waters  Micromass QTOF II, LC-UNKNOWN-QTOF, HIGH
# ├── Micromass Quatro Micro API
# │   ├── UNKNOWN
# │   │   ├── QQ
# │   │   │   ├── ESI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  Micromass Quatro Micro API, UNKNOWN-ESI-QQ, LOW
# │   │   │   └── UNKNOWN
# │   │   │       └── LOW
# │   │   │           └── Waters  Micromass Quatro Micro API, UNKNOWN-UNKNOWN-QQ, LOW
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── LOW
# │   │       │       └── Waters  Micromass Quatro Micro API, UNKNOWN-ESI-UNKNOWN, LOW
# │   │       └── UNKNOWN
# │   │           └── LOW
# │   │               └── Waters  Micromass Quatro Micro API, UNKNOWN-UNKNOWN-UNKNOWN, LOW
# │   └── LC
# │       ├── UNKNOWN
# │       │   ├── ESI
# │       │   │   └── LOW
# │       │   │       └── Waters  Micromass Quatro Micro API, LC-ESI-UNKNOWN, LOW
# │       │   └── UNKNOWN
# │       │       └── LOW
# │       │           └── Waters  Micromass Quatro Micro API, LC-UNKNOWN-UNKNOWN, LOW
# │       └── QQ
# │           └── UNKNOWN
# │               └── LOW
# │                   └── Waters  Micromass Quatro Micro API, LC-UNKNOWN-QQ, LOW
# ├── Micromass Quattro II
# │   ├── UNKNOWN
# │   │   ├── QQQ
# │   │   │   ├── ESI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  Micromass Quattro II, UNKNOWN-ESI-QQQ, LOW
# │   │   │   └── UNKNOWN
# │   │   │       └── LOW
# │   │   │           └── Waters  Micromass Quattro II, UNKNOWN-UNKNOWN-QQQ, LOW
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── LOW
# │   │       │       └── Waters  Micromass Quattro II, UNKNOWN-ESI-UNKNOWN, LOW
# │   │       └── UNKNOWN
# │   │           └── LOW
# │   │               └── Waters  Micromass Quattro II, UNKNOWN-UNKNOWN-UNKNOWN, LOW
# │   └── LC
# │       ├── UNKNOWN
# │       │   ├── ESI
# │       │   │   └── LOW
# │       │   │       └── Waters  Micromass Quattro II, LC-ESI-UNKNOWN, LOW
# │       │   └── UNKNOWN
# │       │       └── LOW
# │       │           └── Waters  Micromass Quattro II, LC-UNKNOWN-UNKNOWN, LOW
# │       └── QQQ
# │           └── UNKNOWN
# │               └── LOW
# │                   └── Waters  Micromass Quattro II, LC-UNKNOWN-QQQ, LOW
# ├── Micromass Quattro Micro
# │   ├── UNKNOWN
# │   │   ├── QQQ
# │   │   │   ├── ESI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  Micromass Quattro Micro, UNKNOWN-ESI-QQQ, LOW
# │   │   │   └── UNKNOWN
# │   │   │       └── LOW
# │   │   │           └── Waters  Micromass Quattro Micro, UNKNOWN-UNKNOWN-QQQ, LOW
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── LOW
# │   │       │       └── Waters  Micromass Quattro Micro, UNKNOWN-ESI-UNKNOWN, LOW
# │   │       └── UNKNOWN
# │   │           └── LOW
# │   │               └── Waters  Micromass Quattro Micro, UNKNOWN-UNKNOWN-UNKNOWN, LOW
# │   └── LC
# │       ├── UNKNOWN
# │       │   ├── ESI
# │       │   │   └── LOW
# │       │   │       └── Waters  Micromass Quattro Micro, LC-ESI-UNKNOWN, LOW
# │       │   └── UNKNOWN
# │       │       └── LOW
# │       │           └── Waters  Micromass Quattro Micro, LC-UNKNOWN-UNKNOWN, LOW
# │       └── QQQ
# │           └── UNKNOWN
# │               └── LOW
# │                   └── Waters  Micromass Quattro Micro, LC-UNKNOWN-QQQ, LOW
# ├── Micromass Quattro Premier
# │   ├── UNKNOWN
# │   │   ├── QQ
# │   │   │   ├── ESI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  Micromass Quattro Premier, UNKNOWN-ESI-QQ, LOW
# │   │   │   └── UNKNOWN
# │   │   │       └── LOW
# │   │   │           └── Waters  Micromass Quattro Premier, UNKNOWN-UNKNOWN-QQ, LOW
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── LOW
# │   │       │       └── Waters  Micromass Quattro Premier, UNKNOWN-ESI-UNKNOWN, LOW
# │   │       └── UNKNOWN
# │   │           └── LOW
# │   │               └── Waters  Micromass Quattro Premier, UNKNOWN-UNKNOWN-UNKNOWN, LOW
# │   └── LC
# │       ├── UNKNOWN
# │       │   ├── ESI
# │       │   │   └── LOW
# │       │   │       └── Waters  Micromass Quattro Premier, LC-ESI-UNKNOWN, LOW
# │       │   └── UNKNOWN
# │       │       └── LOW
# │       │           └── Waters  Micromass Quattro Premier, LC-UNKNOWN-UNKNOWN, LOW
# │       └── QQ
# │           └── UNKNOWN
# │               └── LOW
# │                   └── Waters  Micromass Quattro Premier, LC-UNKNOWN-QQ, LOW
# ├── Micromass Quattro Ultima
# │   ├── UNKNOWN
# │   │   ├── QQ
# │   │   │   ├── ESI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  Micromass Quattro Ultima, UNKNOWN-ESI-QQ, LOW
# │   │   │   └── UNKNOWN
# │   │   │       └── LOW
# │   │   │           └── Waters  Micromass Quattro Ultima, UNKNOWN-UNKNOWN-QQ, LOW
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── LOW
# │   │       │       └── Waters  Micromass Quattro Ultima, UNKNOWN-ESI-UNKNOWN, LOW
# │   │       └── UNKNOWN
# │   │           └── LOW
# │   │               └── Waters  Micromass Quattro Ultima, UNKNOWN-UNKNOWN-UNKNOWN, LOW
# │   └── LC
# │       ├── UNKNOWN
# │       │   ├── ESI
# │       │   │   └── LOW
# │       │   │       └── Waters  Micromass Quattro Ultima, LC-ESI-UNKNOWN, LOW
# │       │   └── UNKNOWN
# │       │       └── LOW
# │       │           └── Waters  Micromass Quattro Ultima, LC-UNKNOWN-UNKNOWN, LOW
# │       └── QQ
# │           └── UNKNOWN
# │               └── LOW
# │                   └── Waters  Micromass Quattro Ultima, LC-UNKNOWN-QQ, LOW
# ├── QTOF Micro
# │   ├── UNKNOWN
# │   │   ├── QTOF
# │   │   │   ├── ESI
# │   │   │   │   └── HIGH
# │   │   │   │       └── Waters  QTOF Micro, UNKNOWN-ESI-QTOF, HIGH
# │   │   │   └── UNKNOWN
# │   │   │       └── HIGH
# │   │   │           └── Waters  QTOF Micro, UNKNOWN-UNKNOWN-QTOF, HIGH
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── HIGH
# │   │       │       └── Waters  QTOF Micro, UNKNOWN-ESI-UNKNOWN, HIGH
# │   │       └── UNKNOWN
# │   │           └── HIGH
# │   │               └── Waters  QTOF Micro, UNKNOWN-UNKNOWN-UNKNOWN, HIGH
# │   └── LC
# │       ├── UNKNOWN
# │       │   ├── ESI
# │       │   │   └── HIGH
# │       │   │       └── Waters  QTOF Micro, LC-ESI-UNKNOWN, HIGH
# │       │   └── UNKNOWN
# │       │       └── HIGH
# │       │           └── Waters  QTOF Micro, LC-UNKNOWN-UNKNOWN, HIGH
# │       └── QTOF
# │           └── UNKNOWN
# │               └── HIGH
# │                   └── Waters  QTOF Micro, LC-UNKNOWN-QTOF, HIGH
# ├── QTOF Premier
# │   ├── UNKNOWN
# │   │   ├── QTOF
# │   │   │   ├── ESI
# │   │   │   │   └── HIGH
# │   │   │   │       └── Waters  QTOF Premier, UNKNOWN-ESI-QTOF, HIGH
# │   │   │   └── UNKNOWN
# │   │   │       └── HIGH
# │   │   │           └── Waters  QTOF Premier, UNKNOWN-UNKNOWN-QTOF, HIGH
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── HIGH
# │   │       │       └── Waters  QTOF Premier, UNKNOWN-ESI-UNKNOWN, HIGH
# │   │       └── UNKNOWN
# │   │           └── HIGH
# │   │               └── Waters  QTOF Premier, UNKNOWN-UNKNOWN-UNKNOWN, HIGH
# │   └── LC
# │       ├── UNKNOWN
# │       │   ├── ESI
# │       │   │   └── HIGH
# │       │   │       └── Waters  QTOF Premier, LC-ESI-UNKNOWN, HIGH
# │       │   └── UNKNOWN
# │       │       └── HIGH
# │       │           └── Waters  QTOF Premier, LC-UNKNOWN-UNKNOWN, HIGH
# │       └── QTOF
# │           └── UNKNOWN
# │               └── HIGH
# │                   └── Waters  QTOF Premier, LC-UNKNOWN-QTOF, HIGH
# ├── Quattro
# │   ├── UNKNOWN
# │   │   ├── QQQ
# │   │   │   ├── ESI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  Quattro, UNKNOWN-ESI-QQQ, LOW
# │   │   │   └── UNKNOWN
# │   │   │       └── LOW
# │   │   │           └── Waters  Quattro, UNKNOWN-UNKNOWN-QQQ, LOW
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── LOW
# │   │       │       └── Waters  Quattro, UNKNOWN-ESI-UNKNOWN, LOW
# │   │       └── UNKNOWN
# │   │           └── LOW
# │   │               └── Waters  Quattro, UNKNOWN-UNKNOWN-UNKNOWN, LOW
# │   └── LC
# │       ├── UNKNOWN
# │       │   ├── ESI
# │       │   │   └── LOW
# │       │   │       └── Waters  Quattro, LC-ESI-UNKNOWN, LOW
# │       │   └── UNKNOWN
# │       │       └── LOW
# │       │           └── Waters  Quattro, LC-UNKNOWN-UNKNOWN, LOW
# │       └── QQQ
# │           └── UNKNOWN
# │               └── LOW
# │                   └── Waters  Quattro, LC-UNKNOWN-QQQ, LOW
# ├── Quattro II
# │   ├── UNKNOWN
# │   │   ├── QQQ
# │   │   │   ├── ESI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  Quattro II, UNKNOWN-ESI-QQQ, LOW
# │   │   │   └── UNKNOWN
# │   │   │       └── LOW
# │   │   │           └── Waters  Quattro II, UNKNOWN-UNKNOWN-QQQ, LOW
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── LOW
# │   │       │       └── Waters  Quattro II, UNKNOWN-ESI-UNKNOWN, LOW
# │   │       └── UNKNOWN
# │   │           └── LOW
# │   │               └── Waters  Quattro II, UNKNOWN-UNKNOWN-UNKNOWN, LOW
# │   └── LC
# │       ├── UNKNOWN
# │       │   ├── ESI
# │       │   │   └── LOW
# │       │   │       └── Waters  Quattro II, LC-ESI-UNKNOWN, LOW
# │       │   └── UNKNOWN
# │       │       └── LOW
# │       │           └── Waters  Quattro II, LC-UNKNOWN-UNKNOWN, LOW
# │       └── QQQ
# │           └── UNKNOWN
# │               └── LOW
# │                   └── Waters  Quattro II, LC-UNKNOWN-QQQ, LOW
# ├── Quattro micro
# │   ├── UNKNOWN
# │   │   ├── QQQ
# │   │   │   ├── ESI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  Quattro micro, UNKNOWN-ESI-QQQ, LOW
# │   │   │   └── UNKNOWN
# │   │   │       └── LOW
# │   │   │           └── Waters  Quattro micro, UNKNOWN-UNKNOWN-QQQ, LOW
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── LOW
# │   │       │       └── Waters  Quattro micro, UNKNOWN-ESI-UNKNOWN, LOW
# │   │       └── UNKNOWN
# │   │           └── LOW
# │   │               └── Waters  Quattro micro, UNKNOWN-UNKNOWN-UNKNOWN, LOW
# │   └── LC
# │       ├── UNKNOWN
# │       │   ├── ESI
# │       │   │   └── LOW
# │       │   │       └── Waters  Quattro micro, LC-ESI-UNKNOWN, LOW
# │       │   └── UNKNOWN
# │       │       └── LOW
# │       │           └── Waters  Quattro micro, LC-UNKNOWN-UNKNOWN, LOW
# │       └── QQQ
# │           └── UNKNOWN
# │               └── LOW
# │                   └── Waters  Quattro micro, LC-UNKNOWN-QQQ, LOW
# ├── Quattro Premier XE
# │   ├── UNKNOWN
# │   │   ├── QIT
# │   │   │   ├── ESI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  Quattro Premier XE, UNKNOWN-ESI-QIT, LOW
# │   │   │   └── UNKNOWN
# │   │   │       └── LOW
# │   │   │           └── Waters  Quattro Premier XE, UNKNOWN-UNKNOWN-QIT, LOW
# │   │   ├── QQ
# │   │   │   ├── ESI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  Quattro Premier XE, UNKNOWN-ESI-QQ, LOW
# │   │   │   └── UNKNOWN
# │   │   │       └── LOW
# │   │   │           └── Waters  Quattro Premier XE, UNKNOWN-UNKNOWN-QQ, LOW
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── LOW
# │   │       │       └── Waters  Quattro Premier XE, UNKNOWN-ESI-UNKNOWN, LOW
# │   │       └── UNKNOWN
# │   │           └── LOW
# │   │               └── Waters  Quattro Premier XE, UNKNOWN-UNKNOWN-UNKNOWN, LOW
# │   └── LC
# │       ├── UNKNOWN
# │       │   ├── ESI
# │       │   │   └── LOW
# │       │   │       └── Waters  Quattro Premier XE, LC-ESI-UNKNOWN, LOW
# │       │   └── UNKNOWN
# │       │       └── LOW
# │       │           └── Waters  Quattro Premier XE, LC-UNKNOWN-UNKNOWN, LOW
# │       ├── QIT
# │       │   └── UNKNOWN
# │       │       └── LOW
# │       │           └── Waters  Quattro Premier XE, LC-UNKNOWN-QIT, LOW
# │       └── QQ
# │           └── UNKNOWN
# │               └── LOW
# │                   └── Waters  Quattro Premier XE, LC-UNKNOWN-QQ, LOW
# ├── SYNAPT
# │   ├── UNKNOWN
# │   │   ├── QTOF
# │   │   │   ├── ESI
# │   │   │   │   └── HIGH
# │   │   │   │       └── Waters  SYNAPT, UNKNOWN-ESI-QTOF, HIGH
# │   │   │   └── UNKNOWN
# │   │   │       └── HIGH
# │   │   │           └── Waters  SYNAPT, UNKNOWN-UNKNOWN-QTOF, HIGH
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── HIGH
# │   │       │       └── Waters  SYNAPT, UNKNOWN-ESI-UNKNOWN, HIGH
# │   │       └── UNKNOWN
# │   │           └── HIGH
# │   │               └── Waters  SYNAPT, UNKNOWN-UNKNOWN-UNKNOWN, HIGH
# │   └── LC
# │       ├── UNKNOWN
# │       │   ├── ESI
# │       │   │   └── HIGH
# │       │   │       └── Waters  SYNAPT, LC-ESI-UNKNOWN, HIGH
# │       │   └── UNKNOWN
# │       │       └── HIGH
# │       │           └── Waters  SYNAPT, LC-UNKNOWN-UNKNOWN, HIGH
# │       └── QTOF
# │           └── UNKNOWN
# │               └── HIGH
# │                   └── Waters  SYNAPT, LC-UNKNOWN-QTOF, HIGH
# ├── SYNAPT-G2
# │   ├── UNKNOWN
# │   │   ├── QTOF
# │   │   │   ├── ESI
# │   │   │   │   └── HIGH
# │   │   │   │       └── Waters  SYNAPT-G2, UNKNOWN-ESI-QTOF, HIGH
# │   │   │   └── UNKNOWN
# │   │   │       └── HIGH
# │   │   │           └── Waters  SYNAPT-G2, UNKNOWN-UNKNOWN-QTOF, HIGH
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── HIGH
# │   │       │       └── Waters  SYNAPT-G2, UNKNOWN-ESI-UNKNOWN, HIGH
# │   │       └── UNKNOWN
# │   │           └── HIGH
# │   │               └── Waters  SYNAPT-G2, UNKNOWN-UNKNOWN-UNKNOWN, HIGH
# │   └── LC
# │       ├── UNKNOWN
# │       │   ├── ESI
# │       │   │   └── HIGH
# │       │   │       └── Waters  SYNAPT-G2, LC-ESI-UNKNOWN, HIGH
# │       │   └── UNKNOWN
# │       │       └── HIGH
# │       │           └── Waters  SYNAPT-G2, LC-UNKNOWN-UNKNOWN, HIGH
# │       └── QTOF
# │           └── UNKNOWN
# │               └── HIGH
# │                   └── Waters  SYNAPT-G2, LC-UNKNOWN-QTOF, HIGH
# ├── Ultima API
# │   ├── UNKNOWN
# │   │   ├── QTOF
# │   │   │   ├── ESI
# │   │   │   │   └── HIGH
# │   │   │   │       └── Waters  Ultima API, UNKNOWN-ESI-QTOF, HIGH
# │   │   │   └── UNKNOWN
# │   │   │       └── HIGH
# │   │   │           └── Waters  Ultima API, UNKNOWN-UNKNOWN-QTOF, HIGH
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── HIGH
# │   │       │       └── Waters  Ultima API, UNKNOWN-ESI-UNKNOWN, HIGH
# │   │       └── UNKNOWN
# │   │           └── HIGH
# │   │               └── Waters  Ultima API, UNKNOWN-UNKNOWN-UNKNOWN, HIGH
# │   └── LC
# │       ├── UNKNOWN
# │       │   ├── ESI
# │       │   │   └── HIGH
# │       │   │       └── Waters  Ultima API, LC-ESI-UNKNOWN, HIGH
# │       │   └── UNKNOWN
# │       │       └── HIGH
# │       │           └── Waters  Ultima API, LC-UNKNOWN-UNKNOWN, HIGH
# │       └── QTOF
# │           └── UNKNOWN
# │               └── HIGH
# │                   └── Waters  Ultima API, LC-UNKNOWN-QTOF, HIGH
# ├── VG platform
# │   ├── UNKNOWN
# │   │   ├── Q
# │   │   │   ├── APCI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  VG platform, UNKNOWN-APCI-Q, LOW
# │   │   │   └── UNKNOWN
# │   │   │       └── LOW
# │   │   │           └── Waters  VG platform, UNKNOWN-UNKNOWN-Q, LOW
# │   │   └── UNKNOWN
# │   │       ├── APCI
# │   │       │   └── LOW
# │   │       │       └── Waters  VG platform, UNKNOWN-APCI-UNKNOWN, LOW
# │   │       └── UNKNOWN
# │   │           └── LOW
# │   │               └── Waters  VG platform, UNKNOWN-UNKNOWN-UNKNOWN, LOW
# │   └── LC
# │       ├── UNKNOWN
# │       │   ├── APCI
# │       │   │   └── LOW
# │       │   │       └── Waters  VG platform, LC-APCI-UNKNOWN, LOW
# │       │   └── UNKNOWN
# │       │       └── LOW
# │       │           └── Waters  VG platform, LC-UNKNOWN-UNKNOWN, LOW
# │       └── Q
# │           └── UNKNOWN
# │               └── LOW
# │                   └── Waters  VG platform, LC-UNKNOWN-Q, LOW
# ├── Xevo
# │   ├── UNKNOWN
# │   │   ├── QTOF
# │   │   │   ├── ESI
# │   │   │   │   └── HIGH
# │   │   │   │       └── Waters  Xevo, UNKNOWN-ESI-QTOF, HIGH
# │   │   │   └── UNKNOWN
# │   │   │       └── HIGH
# │   │   │           └── Waters  Xevo, UNKNOWN-UNKNOWN-QTOF, HIGH
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── HIGH
# │   │       │       └── Waters  Xevo, UNKNOWN-ESI-UNKNOWN, HIGH
# │   │       └── UNKNOWN
# │   │           └── HIGH
# │   │               └── Waters  Xevo, UNKNOWN-UNKNOWN-UNKNOWN, HIGH
# │   └── LC
# │       ├── UNKNOWN
# │       │   ├── ESI
# │       │   │   └── HIGH
# │       │   │       └── Waters  Xevo, LC-ESI-UNKNOWN, HIGH
# │       │   └── UNKNOWN
# │       │       └── HIGH
# │       │           └── Waters  Xevo, LC-UNKNOWN-UNKNOWN, HIGH
# │       └── QTOF
# │           └── UNKNOWN
# │               └── HIGH
# │                   └── Waters  Xevo, LC-UNKNOWN-QTOF, HIGH
# ├── Xevo G2
# │   ├── UNKNOWN
# │   │   ├── QTOF
# │   │   │   ├── ESI
# │   │   │   │   └── HIGH
# │   │   │   │       └── Waters  Xevo G2, UNKNOWN-ESI-QTOF, HIGH
# │   │   │   └── UNKNOWN
# │   │   │       └── HIGH
# │   │   │           └── Waters  Xevo G2, UNKNOWN-UNKNOWN-QTOF, HIGH
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── HIGH
# │   │       │       └── Waters  Xevo G2, UNKNOWN-ESI-UNKNOWN, HIGH
# │   │       └── UNKNOWN
# │   │           └── HIGH
# │   │               └── Waters  Xevo G2, UNKNOWN-UNKNOWN-UNKNOWN, HIGH
# │   └── LC
# │       ├── UNKNOWN
# │       │   ├── ESI
# │       │   │   └── HIGH
# │       │   │       └── Waters  Xevo G2, LC-ESI-UNKNOWN, HIGH
# │       │   └── UNKNOWN
# │       │       └── HIGH
# │       │           └── Waters  Xevo G2, LC-UNKNOWN-UNKNOWN, HIGH
# │       └── QTOF
# │           └── UNKNOWN
# │               └── HIGH
# │                   └── Waters  Xevo G2, LC-UNKNOWN-QTOF, HIGH
# ├── Xevo G2-S
# │   ├── UNKNOWN
# │   │   ├── QTOF
# │   │   │   ├── ESI
# │   │   │   │   └── HIGH
# │   │   │   │       └── Waters  Xevo G2-S, UNKNOWN-ESI-QTOF, HIGH
# │   │   │   └── UNKNOWN
# │   │   │       └── HIGH
# │   │   │           └── Waters  Xevo G2-S, UNKNOWN-UNKNOWN-QTOF, HIGH
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── HIGH
# │   │       │       └── Waters  Xevo G2-S, UNKNOWN-ESI-UNKNOWN, HIGH
# │   │       └── UNKNOWN
# │   │           └── HIGH
# │   │               └── Waters  Xevo G2-S, UNKNOWN-UNKNOWN-UNKNOWN, HIGH
# │   └── LC
# │       ├── UNKNOWN
# │       │   ├── ESI
# │       │   │   └── HIGH
# │       │   │       └── Waters  Xevo G2-S, LC-ESI-UNKNOWN, HIGH
# │       │   └── UNKNOWN
# │       │       └── HIGH
# │       │           └── Waters  Xevo G2-S, LC-UNKNOWN-UNKNOWN, HIGH
# │       └── QTOF
# │           └── UNKNOWN
# │               └── HIGH
# │                   └── Waters  Xevo G2-S, LC-UNKNOWN-QTOF, HIGH
# ├── Xevo G2-XS
# │   ├── UNKNOWN
# │   │   ├── QTOF
# │   │   │   ├── ESI
# │   │   │   │   └── HIGH
# │   │   │   │       └── Waters  Xevo G2-XS, UNKNOWN-ESI-QTOF, HIGH
# │   │   │   └── UNKNOWN
# │   │   │       └── HIGH
# │   │   │           └── Waters  Xevo G2-XS, UNKNOWN-UNKNOWN-QTOF, HIGH
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── HIGH
# │   │       │       └── Waters  Xevo G2-XS, UNKNOWN-ESI-UNKNOWN, HIGH
# │   │       └── UNKNOWN
# │   │           └── HIGH
# │   │               └── Waters  Xevo G2-XS, UNKNOWN-UNKNOWN-UNKNOWN, HIGH
# │   └── LC
# │       ├── UNKNOWN
# │       │   ├── ESI
# │       │   │   └── HIGH
# │       │   │       └── Waters  Xevo G2-XS, LC-ESI-UNKNOWN, HIGH
# │       │   └── UNKNOWN
# │       │       └── HIGH
# │       │           └── Waters  Xevo G2-XS, LC-UNKNOWN-UNKNOWN, HIGH
# │       └── QTOF
# │           └── UNKNOWN
# │               └── HIGH
# │                   └── Waters  Xevo G2-XS, LC-UNKNOWN-QTOF, HIGH
# ├── Xevo TQ
# │   ├── UNKNOWN
# │   │   ├── QQ
# │   │   │   ├── ESI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  Xevo TQ, UNKNOWN-ESI-QQ, LOW
# │   │   │   └── UNKNOWN
# │   │   │       └── LOW
# │   │   │           └── Waters  Xevo TQ, UNKNOWN-UNKNOWN-QQ, LOW
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── LOW
# │   │       │       └── Waters  Xevo TQ, UNKNOWN-ESI-UNKNOWN, LOW
# │   │       └── UNKNOWN
# │   │           └── LOW
# │   │               └── Waters  Xevo TQ, UNKNOWN-UNKNOWN-UNKNOWN, LOW
# │   └── LC
# │       ├── UNKNOWN
# │       │   ├── ESI
# │       │   │   └── LOW
# │       │   │       └── Waters  Xevo TQ, LC-ESI-UNKNOWN, LOW
# │       │   └── UNKNOWN
# │       │       └── LOW
# │       │           └── Waters  Xevo TQ, LC-UNKNOWN-UNKNOWN, LOW
# │       └── QQ
# │           └── UNKNOWN
# │               └── LOW
# │                   └── Waters  Xevo TQ, LC-UNKNOWN-QQ, LOW
# ├── Xevo TQD
# │   ├── UNKNOWN
# │   │   ├── QQQ
# │   │   │   ├── ESI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  Xevo TQD, UNKNOWN-ESI-QQQ, LOW
# │   │   │   └── UNKNOWN
# │   │   │       └── LOW
# │   │   │           └── Waters  Xevo TQD, UNKNOWN-UNKNOWN-QQQ, LOW
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── LOW
# │   │       │       └── Waters  Xevo TQD, UNKNOWN-ESI-UNKNOWN, LOW
# │   │       └── UNKNOWN
# │   │           └── LOW
# │   │               └── Waters  Xevo TQD, UNKNOWN-UNKNOWN-UNKNOWN, LOW
# │   └── LC
# │       ├── UNKNOWN
# │       │   ├── ESI
# │       │   │   └── LOW
# │       │   │       └── Waters  Xevo TQD, LC-ESI-UNKNOWN, LOW
# │       │   └── UNKNOWN
# │       │       └── LOW
# │       │           └── Waters  Xevo TQD, LC-UNKNOWN-UNKNOWN, LOW
# │       └── QQQ
# │           └── UNKNOWN
# │               └── LOW
# │                   └── Waters  Xevo TQD, LC-UNKNOWN-QQQ, LOW
# ├── Xevo TQS Micro
# │   ├── UNKNOWN
# │   │   ├── QQ
# │   │   │   ├── ESI
# │   │   │   │   └── LOW
# │   │   │   │       └── Waters  Xevo TQS Micro, UNKNOWN-ESI-QQ, LOW
# │   │   │   └── UNKNOWN
# │   │   │       └── LOW
# │   │   │           └── Waters  Xevo TQS Micro, UNKNOWN-UNKNOWN-QQ, LOW
# │   │   └── UNKNOWN
# │   │       ├── ESI
# │   │       │   └── LOW
# │   │       │       └── Waters  Xevo TQS Micro, UNKNOWN-ESI-UNKNOWN, LOW
# │   │       └── UNKNOWN
# │   │           └── LOW
# │   │               └── Waters  Xevo TQS Micro, UNKNOWN-UNKNOWN-UNKNOWN, LOW
# │   └── LC
# │       ├── UNKNOWN
# │       │   ├── ESI
# │       │   │   └── LOW
# │       │   │       └── Waters  Xevo TQS Micro, LC-ESI-UNKNOWN, LOW
# │       │   └── UNKNOWN
# │       │       └── LOW
# │       │           └── Waters  Xevo TQS Micro, LC-UNKNOWN-UNKNOWN, LOW
# │       └── QQ
# │           └── UNKNOWN
# │               └── LOW
# │                   └── Waters  Xevo TQS Micro, LC-UNKNOWN-QQ, LOW
# └── ZQ
#     ├── UNKNOWN
#     │   ├── ITTOF
#     │   │   ├── APCI
#     │   │   │   └── HIGH
#     │   │   │       └── Waters  ZQ, UNKNOWN-APCI-ITTOF, HIGH
#     │   │   └── UNKNOWN
#     │   │       └── HIGH
#     │   │           └── Waters  ZQ, UNKNOWN-UNKNOWN-ITTOF, HIGH
#     │   └── UNKNOWN
#     │       ├── APCI
#     │       │   └── HIGH
#     │       │       └── Waters  ZQ, UNKNOWN-APCI-UNKNOWN, HIGH
#     │       └── UNKNOWN
#     │           └── HIGH
#     │               └── Waters  ZQ, UNKNOWN-UNKNOWN-UNKNOWN, HIGH
#     └── LC
#         ├── UNKNOWN
#         │   ├── APCI
#         │   │   └── HIGH
#         │   │       └── Waters  ZQ, LC-APCI-UNKNOWN, HIGH
#         │   └── UNKNOWN
#         │       └── HIGH
#         │           └── Waters  ZQ, LC-UNKNOWN-UNKNOWN, HIGH
#         └── ITTOF
#             └── UNKNOWN
#                 └── HIGH
#                     └── Waters  ZQ, LC-UNKNOWN-ITTOF, HIGH
